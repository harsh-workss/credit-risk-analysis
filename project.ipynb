# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Harsh Yadav\Harsh Notebook\Delinquency_prediction_dataset.csv.csv")
print(df.head())
# Out:
#   Customer_ID  Age    Income  Credit_Score  Credit_Utilization  \
# 0    CUST0001   56  165580.0         398.0            0.390502
# 1    CUST0002   69  100999.0         493.0            0.312444
# 2    CUST0003   46  188416.0         500.0            0.359930
# 3    CUST0004   32  101672.0         413.0            0.371400
# 4    CUST0005   60   38524.0         487.0            0.234716
#
#    Missed_Payments  Delinquent_Account  Loan_Balance  Debt_to_Income_Ratio  \
# 0                3                   0       16310.0              0.317396
# 1                6                   1       17401.0              0.196093
# 2                0                   0       13761.0              0.301655
# 3                3                   0       88778.0              0.264794
# 4                2                   0       13316.0              0.510583
#
#   Employment_Status  Account_Tenure Credit_Card_Type     Location Month_1  \
# ...

# %%
print(df.shape)
# Out:
# (500, 19)

# %%
df.describe()
# Out:
#               Age         Income  Credit_Score  Credit_Utilization  \
# count  500.000000     461.000000    498.000000          500.000000
# mean    46.266000  108379.893709    577.716867            0.491446
# std     16.187629   53662.723741    168.881211            0.197103
# min     18.000000   15404.000000    301.000000            0.050000
# 25%     33.000000   62295.000000    418.250000            0.356486
# 50%     46.500000  107658.000000    586.000000            0.485636
# 75%     59.250000  155734.000000    727.250000            0.634440
# max     74.000000  199943.000000    847.000000            1.025843
#
#        Missed_Payments  Delinquent_Account  Loan_Balance  \
# count       500.000000          500.000000    471.000000
# mean          2.968000            0.160000  48654.428875
# std           1.946935            0.366973  29395.537273
# min           0.000000            0.000000    612.000000
# 25%           1.000000            0.000000  23716.500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer_ID           500 non-null    object
#  1   Age                   500 non-null    int64
#  2   Income                461 non-null    float64
#  3   Credit_Score          498 non-null    float64
#  4   Credit_Utilization    500 non-null    float64
#  5   Missed_Payments       500 non-null    int64
#  6   Delinquent_Account    500 non-null    int64
#  7   Loan_Balance          471 non-null    float64
#  8   Debt_to_Income_Ratio  500 non-null    float64
#  9   Employment_Status     500 non-null    object
#  10  Account_Tenure        500 non-null    int64
#  11  Credit_Card_Type      500 non-null    object
#  12  Location              500 non-null    object
#  13  Month_1               500 non-null    object
#  14  Month_2               500 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Income                  39
# Credit_Score             2
# Credit_Utilization       0
# Missed_Payments          0
# Delinquent_Account       0
# Loan_Balance            29
# Debt_to_Income_Ratio     0
# Employment_Status        0
# Account_Tenure           0
# Credit_Card_Type         0
# Location                 0
# Month_1                  0
# Month_2                  0
# Month_3                  0
# Month_4                  0
# Month_5                  0
# Month_6                  0
# dtype: int64

# %%
df['Delinquent_Account'].value_counts()
# Out:
# Delinquent_Account
# 0    420
# 1     80
# Name: count, dtype: int64

# %%
df['Income'] = df['Income'].fillna(df['Income'].median())
print(df)
# Out:
#     Customer_ID  Age    Income  Credit_Score  Credit_Utilization  \
# 0      CUST0001   56  165580.0         500.0            0.390502
# 1      CUST0002   69  100999.0         500.0            0.312444
# 2      CUST0003   46  188416.0         500.0            0.359930
# 3      CUST0004   32  101672.0         500.0            0.371400
# 4      CUST0005   60   38524.0         500.0            0.234716
# ..          ...  ...       ...           ...                 ...
# 495    CUST0496   71   48307.0         500.0            0.486522
# 496    CUST0497   60   86180.0         500.0            0.608174
# 497    CUST0498   54  152326.0         500.0            0.676950
# 498    CUST0499   50  105852.0         500.0            0.700643
# 499    CUST0500   25   40945.0         500.0            0.911370
#
#      Missed_Payments  Delinquent_Account  Loan_Balance  Debt_to_Income_Ratio  \
# 0                  3                   0       16310.0              0.317396
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Income                   0
# Credit_Score             0
# Credit_Utilization       0
# Missed_Payments          0
# Delinquent_Account       0
# Loan_Balance            29
# Debt_to_Income_Ratio     0
# Employment_Status        0
# Account_Tenure           0
# Credit_Card_Type         0
# Location                 0
# Month_1                  0
# Month_2                  0
# Month_3                  0
# Month_4                  0
# Month_5                  0
# Month_6                  0
# dtype: int64

# %%
df
# Out:
#     Customer_ID  Age    Income  Credit_Score  Credit_Utilization  \
# 0      CUST0001   56  165580.0         500.0            0.390502
# 1      CUST0002   69  100999.0         500.0            0.312444
# 2      CUST0003   46  188416.0         500.0            0.359930
# 3      CUST0004   32  101672.0         500.0            0.371400
# 4      CUST0005   60   38524.0         500.0            0.234716
# ..          ...  ...       ...           ...                 ...
# 495    CUST0496   71   48307.0         500.0            0.486522
# 496    CUST0497   60   86180.0         500.0            0.608174
# 497    CUST0498   54  152326.0         500.0            0.676950
# 498    CUST0499   50  105852.0         500.0            0.700643
# 499    CUST0500   25   40945.0         500.0            0.911370
#
#      Missed_Payments  Delinquent_Account  Loan_Balance  Debt_to_Income_Ratio  \
# 0                  3                   0       16310.0              0.317396
# ...

# %%
df['Loan_Balance'].fillna(df['Loan_Balance'].median())
print(df)
# Out:
#     Customer_ID  Age    Income  Credit_Score  Credit_Utilization  \
# 0      CUST0001   56  165580.0         500.0            0.390502
# 1      CUST0002   69  100999.0         500.0            0.312444
# 2      CUST0003   46  188416.0         500.0            0.359930
# 3      CUST0004   32  101672.0         500.0            0.371400
# 4      CUST0005   60   38524.0         500.0            0.234716
# ..          ...  ...       ...           ...                 ...
# 495    CUST0496   71   48307.0         500.0            0.486522
# 496    CUST0497   60   86180.0         500.0            0.608174
# 497    CUST0498   54  152326.0         500.0            0.676950
# 498    CUST0499   50  105852.0         500.0            0.700643
# 499    CUST0500   25   40945.0         500.0            0.911370
#
#      Missed_Payments  Delinquent_Account  Loan_Balance  Debt_to_Income_Ratio  \
# 0                  3                   0       16310.0              0.317396
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Age                     0
# Income                  0
# Credit_Score            0
# Credit_Utilization      0
# Missed_Payments         0
# Delinquent_Account      0
# Loan_Balance            0
# Debt_to_Income_Ratio    0
# Employment_Status       0
# Account_Tenure          0
# Credit_Card_Type        0
# Location                0
# Month_1                 0
# Month_2                 0
# Month_3                 0
# Month_4                 0
# Month_5                 0
# Month_6                 0
# dtype: int64

# %%
df.groupby('Delinquent_Account')['Credit_Score'].mean()
# Out:
# Delinquent_Account
# 0    500.0
# 1    500.0
# Name: Credit_Score, dtype: float64

# %%
#step 3
plt.figure(figsize=(12, 6))
# your plot code
plt.plot()  # or whatever you're using
plt.title("Customer Credit Score Distribution")
plt.savefig("credit_score_plot.png")  # Saves in your current folder
plt.show()
